# %% [markdown]
# Ветки знаний Data science.

# %% [markdown]
# Матан:
#     1 Градиент
#     2 Интеграл
#     3 Производные
#     4 Предел
#     5 Теория множеств

# %% [markdown]
# Линал:
#     1 Сингулярное разложение
#     2 Векторы
#     3 Собственный вектор матрицы
#     4 Матрицы
#     5 Линейная комбинация векторов
#     6 Операции над векторами и матрицами
#     7 Линейное преобразование векторов

# %% [markdown]
# Статистика:
#     1 P-value
#     2 Доверительные интералы
#     3 Плотность распределения
#     4 Важные статистики (выборочное среднее, мода...)
#     5 Характеристики распределений (медиана, дисперсия...)
#     6 Центральная предельная теорема
#     7 Корреляция + ловушки (парадокс Симпсона)

# %% [markdown]
# Теория вероятностей:
#     1 Свойства вероятности
#     2 Дискреткные случайные величины
#     3 Услованая вероятность
#     4 Непрерывные случайные величины
#     5 Теорема Байеса
#     6 Формула полной вероятности

# %% [markdown]
# Визуализация:
#     1 Графики
#     2 Диграммы
#     3 EDA (Exploratory Data Analysis)

# %% [markdown]
# Программирование:
#     1 R
#     2 Bash
#     3 Java, Scala (Big Data)
#     4 SQL
#     5 Python

# %% [markdown]
# Алгоритмы:
#     1 Text mining / NLP
#     2 Обучение с учителем:
#         Классификация:
#             Деревья решений
#             Логистическая регрессия
#             Метод опорных векторов
#             Бустинги (несколько)
#             Наивный байесовский классификатор
#             Sentiment analysis (+ без учителя)
#         Нейросети:
#             Backpropagation
#             Deep Learning (GAN, CNN)
#         Регрессия:
#             Бустинги
#             Деревья решений
#             Регрессия Lasso, Ridge
#             Линейная регрессия
#     3 Обучение без учителя:
#         Кластеризация:
#             DBSCAN
#             Иерархическая класстеризация
#             Метод к-средних
#             Spectral clustering
#         Нейросети:
#             Нейронная сеть Кохонена
#             Глубокая сеть доверия
#     4 Рекомендательные системы:
#         Коллаборативная фильтрация
#         Гибридные модели
#         Рекомендации на основе контента
